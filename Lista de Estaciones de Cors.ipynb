# %%
#Download conus data 2003 day 324
import wget
from ftplib import FTP
host='geodesy.noaa.gov'
directory='/cors/rinex/2003/324/'
f=FTP(host)
f.login()
f.cwd(directory) # Cambia directorio
print "Carpetas en dia 324"
stations=f.nlst()
# Out:
# Carpetas en dia 324

# %%
stations=[i for i in stations if len(i)==4]
stations
# Out:
# ['1lsu',
#  '1ulm',
#  'abq1',
#  'acu1',
#  'adks',
#  'adri',
#  'ais1',
#  'amc2',
#  'ang1',
#  'ang2',
#  'anp1',
#  'aoml',
#  'arp3',
#  'ashv',
#  'aspa',
#  'asub',
#  'avca',
#  'azcn',
#  'azgb',
#  'barh',
#  'barn',
#  'bay1',
#  'bay2',
#  'bayr',
#  'bfny',
#  'bil1',
#  'bill',
#  'bis1',
#  'blkv',
#  'blmm',
#  'blrw',
#  'blyt',
#  'brig',
#  'brmu',
#  'brtw',
#  'bru1',
#  'bsmk',
#  'burn',
#  'bvhs',
#  'cabl',
#  'calu',
#  'carh',
#  'casl',
#  'casp',
#  'cass',
#  'ccv3',
#  'cdb7',
#  'cena',
#  'chab',
#  'chb1',
#  'chi3',
#  'chme',
#  'cho1',
#  'chzz',
#  'clk1',
#  'clre',
#  'cmbb',
#  'cme1',
#  'cndr',
#  'cnmr',
#  'cnwm',
#  'cola',
#  'colb',
#  'cono',
#  'corb',
#  'corv',
#  'cosa',
#  'coso',
#  'cot1',
#  'cot2',
#  'covx',
#  'cpxf',
#  'crlt',
#  'cro1',
#  'ddsn',
#  'defi',
#  'det2',
#  'dfnk',
#  'dhlg',
#  'dnrc',
#  'dobs',
#  'dqua',
#  'drv1',
#  'dsl1',
#  'dsrc',
#  'duck',
#  'edoc',
#  'elen',
#  'eng2',
#  'eprt',
# ...

# %%
outfile=open("conus324.txt","wb")

# %%
outfile.write(str(stations))
